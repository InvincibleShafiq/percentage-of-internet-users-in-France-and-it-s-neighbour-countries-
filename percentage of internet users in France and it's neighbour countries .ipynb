# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import datetime
import random
import seaborn as sns

# %%
import os

# %%
df=pd.read_csv(r'gapminder_internet.csv')

# %%
df.set_index('country')

df.set_index('country')['Finland' :'Germany']

dfs=df.set_index('country')['Finland' :'Germany']

dfs.head()
# Out:
#                   incomeperperson  internetuserate  urbanrate
# country
# Finland              27110.731590        86.898845      63.30
# France               22878.466570        77.498619      77.36
# French Polynesia              NaN        48.957328      51.64
# Gabon                 4180.765821         7.232224      85.04
# Gambia                 354.599726         9.196775      56.42

# %%
dfs.plot(kind='bar',figsize=(12,5))
plt.title('Percentage of  internetuserate')
# Out:
# Text(0.5, 1.0, 'Percentage of  internetuserate')

# %%
dfs.plot(figsize=(12,5))
plt.title('Percentage of  internetuserate')
# Out:
# Text(0.5, 1.0, 'Percentage of  internetuserate')
